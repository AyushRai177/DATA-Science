# %%
2 + 2
# Out:
# 4

# %% [markdown]
# # This is Heading

# %% [markdown]
# # python Basics
#
# ### level 01
# -variables
# -input output
# -operators
# -datatypes
#
# ### level 02
# -conditonal statements
#     -if
#     -ifelse
#     -elif
# -match
# -loo

# %%
age=10
is_married=False
name='bob'
value=1.323

# %%
x=...

# %%
x=10 ** 4299
print(x)
# Out:
# ...

# %%
x=1.10
y=1.0
z=-35.59
z=87.7e100

# %%
name="bruce wayne 01"
color="yellow"
institution="digipodium"

# %%
is_coding=True
is_fun=True
are_u_bored=False

# %%
x=None

# %%
a=[5,10,15,20,25,30,35,40,45]
vals=[1,2.2,'python']

# %%
a={5,10,15,20,25,30,35,40,45}
vals={1,2.2,'python'}
colors={'red','green','yellow'}

# %%
car_info={"brand":"Ford"
}

# %%
x=9
y=10

# %%
print(x+y)
print(x-y)
print(x*y)
print(x/y)
print(x//y)
print(x%y)
print(x//y)
# Out:
# 19
# -1
# 90
# 0.9
# 0
# 9
# 0

# %% [markdown]
# operator precidence =
# 1. * / // ** %

# %%
2**3+5/3
# Out:
# 9.666666666666666

# %%
(3+2)*(5*3)/(3*5)
# Out:
# 5.0

# %%
a=100
a +=15
a-=10

# %%
a*=10
a%=5
print(a)
# Out:
# 0

# %% [markdown]
# comparison operator

# %%
x=10
y=20
print(x>y)
print(x<y)
print(x==100)
print(x!=30)
print(x>=50)
print(y<=20)
print('hello' =='hellow')
print('Hi'!="HI")
print("this" ==" that")
# Out:
# False
# True
# False
# True
# False
# True
# False
# True
# False
